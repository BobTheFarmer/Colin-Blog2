# %% [markdown]
# # JavaScript Final

# %%
# %%html
# <head>
#     <!-- load jQuery and DataTables syle and scripts -->
#     <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.4/css/jquery.dataTables.min.css">
#     <script type="text/javascript" language="javascript" src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
#     <script>var define = null;</script>
#     <script type="text/javascript" language="javascript" src="https://cdn.datatables.net/1.13.4/js/jquery.dataTables.min.js"></script>
# </head>
# <table id="flaskTable" class="table" style="width:100%">
#     <thead id="flaskHead">
#         <tr>
#             <th>ID</th>
#             <th>Name</th>
#             <th>DOB</th>
#             <th>Age</th>
#         </tr>
#     </thead>
#     <tbody id="flaskBody"></tbody>
# </table>
#
# <script>
#   $(document).ready(function() {
#     fetch('https://flask.nighthawkcodingsociety.com/api/users/', { mode: 'cors' })
#     .then(response => {
#       if (!response.ok) {
#         throw new Error('API response failed');
#       }
#       return response.json();
#     })
#     .then(data => {
#       for (const row of data) {
#         // BUG warning/resolution - DataTable requires row to be single append
#         $('#flaskBody').append('<tr><td>' +
#             row.id + '</td><td>' +
#             row.name + '</td><td>' +
#             row.dob + '</td><td>' +
#             row.age + '</td></tr>');
#       }
#       // BUG warning - Jupyter does not show Datatable controls, works on deployed GitHub pages
#       $("#flaskTable").DataTable();
#     })
#     .catch(error => {
#       console.error('Error:', error);
#     });
#   });
# </script>

# %%
# %%html
# <head>
#     <script type="text/javascript" language="javascript" src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
#     <script>var define = null;</script>
#     <script type="text/javascript" language="javascript" src="https://cdn.datatables.net/1.13.4/js/jquery.dataTables.min.js"></script>
#     <style>
#         .fisherman {
#             position: absolute;
#             left: 335px;
#             top: 230px;
#         }
#         .hut {
#             position: absolute;
#             top: 200px;
#             left: 8px;
#         }
#         .water {
#             position: absolute;
#             top: 274px;
#             height: 58px;
#         }
#         .container {
#             position: absolute;
#             height: 500px;
#         }
#         .background {
#             object-fit: cover;
#         }
#         .boat {
#             position: absolute;
#             top: 265px;
#             left: 300px;
#         }
#     </style>
# </head>
# <img class="background" src="images/fishing/background.png"></img>
# <img class="hut" src="images/fishing/hut.png"></img>
# <img class="water" src="images/fishing/water.png" style="left: 8px"></img>
# <img class="water" src="images/fishing/water.png" style="left: 200px"></img>
# <img class="water" src="images/fishing/water.png" style="left: 392px"></img>
#
# <img class="fisherman" id="fisherman" src="images/fishing/hook1.png"></img>
# <img class="boat" src="images/fishing/boat.png"></img>
#
# <script>
#     $(document).ready(function() {
#         const fisherman = document.getElementById("fisherman");
#         const waterBlocks = document.getElementsByClassName("water");
#         const boat = document.getElementsByClassName("boat");
#         status = 0;
#         frame = 1;
#         wavesFrame = 1;
#
#         //Set up animation timer
#         function animate() {
#             /*switch(status) {
#                 case 0: //Idle
#                     switch(frame) {
#                         case 1:
#                             fisherman.src = "images/fishing/hook2.png";
#                             frame = 2;
#                             break;
#                         case 2:
#                             fisherman.src = "images/fishing/hook3.png";
#                             frame = 3;
#                             break;
#                         case 3:
#                             fisherman.src = "images/fishing/hook4.png";
#                             frame = 4;
#                             break;
#                         case 4:
#                             fisherman.src = "images/fishing/hook5.png";
#                             frame = 5;
#                             break;
#                         case 5:
#                             fisherman.src = "images/fishing/hook1.png";
#                             frame = 1;
#                             break;
#                     }
#             }*/
#
#             if(status == 0) { //Idle
#                 if(frame == 1) {
#                     fisherman.src = "images/fishing/idle2.png";
#                     frame = 2;
#                 } else {
#                     fisherman.src = "images/fishing/idle1.png";
#                     frame = 1;
#                 }
#             } else if(status == 1) { //Caught fish
#                 /*src += "idle"
#                 if(frame < 4) {
#                     src += (frame+1) + ".png"
#                     frame +=1;
#                 } else {
#                     src += "idle1.png"
#                     frame = 1;
#                 }*/
#             }
#         }
#
#         function waves() {
#             waterLevelChange = int(10*sin(waterFrame));
#
#
#             waterBlocks.forEach(element => element.style.top = (274 + waterLevelChange) + "px");
#             boat.style.top = (265 + waterLevelChange) + "px";
#             fisherman.style.top = (230 + waterLevelChange) + "px";
#             waterFrame = waterFrame + 1;
#         }
#
#
#         function setFishermanStatus(newStatus) {
#             frame = 1;
#             if(newStatus == "idle") {
#                 status = 0;
#             } else if(newStatus == "hook") {
#                 status = 1;
#             } else {
#                 console.log("Error, status set to invalid value");
#             }
#         }
#
#
#
#         //Start
#         setInterval(animate, 500);
#         setInterval(waves, 20);
#     });
# </script>
# Out:
# <head>
#     <script type="text/javascript" language="javascript" src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
#     <script>var define = null;</script>
#     <script type="text/javascript" language="javascript" src="https://cdn.datatables.net/1.13.4/js/jquery.dataTables.min.js"></script>
#     <style>
#         .fisherman {
#             position: absolute;
#             left: 335px;
#             top: 230px;
#         }
#         .hut {
#             position: absolute;
#             top: 200px;
#             left: 8px;
#         }
#         .water {
#             position: absolute;
#             top: 274px;
#             height: 58px;
#         }
#         .container {
#             position: absolute;
#             height: 500px;
#         }
#         .background {
#             object-fit: cover;
#         }
#         .boat {
#             position: absolute;
#             top: 265px;
#             left: 300px;
#         }
#     </style>
# </head>
# <img class="background" src="images/fishing/background.png"></img>
# <img class="hut" src="images/fishing/hut.png"></img>
# <img class="water" src="images/fishing/water.png" style="left: 8px"></img>
# <img class="water" src="images/fishing/water.png" style="left: 200px"></img>
# <img class="water" src="images/fishing/water.png" style="left: 392px"></img>
#
# <img class="fisherman" id="fisherman" src="images/fishing/hook1.png"></img>
# <img class="boat" src="images/fishing/boat.png"></img>
#
# <script>
#     $(document).ready(function() {
#         const fisherman = document.getElementById("fisherman");
#         const waterBlocks = document.getElementsByClassName("water");
#         const boat = document.getElementsByClassName("boat");
#         status = 0;
#         frame = 1;
#         wavesFrame = 1;
#
#         //Set up animation timer
#         function animate() {
#             /*switch(status) {
#                 case 0: //Idle
#                     switch(frame) {
#                         case 1:
#                             fisherman.src = "images/fishing/hook2.png";
#                             frame = 2;
#                             break;
#                         case 2:
#                             fisherman.src = "images/fishing/hook3.png";
#                             frame = 3;
#                             break;
#                         case 3:
#                             fisherman.src = "images/fishing/hook4.png";
#                             frame = 4;
#                             break;
#                         case 4:
#                             fisherman.src = "images/fishing/hook5.png";
#                             frame = 5;
#                             break;
#                         case 5:
#                             fisherman.src = "images/fishing/hook1.png";
#                             frame = 1;
#                             break;
#                     }
#             }*/
#
#             if(status == 0) { //Idle
#                 if(frame == 1) {
#                     fisherman.src = "images/fishing/idle2.png";
#                     frame = 2;
#                 } else {
#                     fisherman.src = "images/fishing/idle1.png";
#                     frame = 1;
#                 }
#             } else if(status == 1) { //Caught fish
#                 /*src += "idle"
#                 if(frame < 4) {
#                     src += (frame+1) + ".png"
#                     frame +=1;
#                 } else {
#                     src += "idle1.png"
#                     frame = 1;
#                 }*/
#             }
#         }
#
#         function waves() {
#             waterLevelChange = int(10*sin(waterFrame));
#
#
#             waterBlocks.forEach(element => element.style.top = (274 + waterLevelChange) + "px");
#             boat.style.top = (265 + waterLevelChange) + "px";
#             fisherman.style.top = (230 + waterLevelChange) + "px";
#             waterFrame+=1;
#         }
#
#
#         function setFishermanStatus(newStatus) {
#             frame = 1;
#             if(newStatus == "idle") {
#                 status = 0;
#             } else if(newStatus == "hook") {
#                 status = 1;
#             } else {
#                 console.log("Error, status set to invalid value");
#             }
#         }
#
#
#
#         //Start
#         setInterval(animate, 500);
#         setInterval(waves, 20);
#     });
# </script>
